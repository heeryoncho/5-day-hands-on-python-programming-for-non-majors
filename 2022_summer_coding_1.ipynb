# %% [markdown]
# <mark><font size=3>**중앙대학교 인문콘텐츠연구소 비전공자를 위한 2022 여름 프로그래밍 강좌 (1/5)**</font></mark><br/>
# <font color=MediumSeaGreen size=5>**Colab을 활용한 파이썬 텍스트 분석 입문**</font>  <font color=black size=5></font> 🐍
#
# ---

# %% [markdown]
# ---
# \[유익한 교재\]
#
# https://github.com/sparklingmin/LangComp2021/blob/main/slides/02-20210906.pdf

# %% [markdown]
# 1. 먼저 Gmail 계정으로 로그인해 주세요.
# 2. 아래의 링크를 클릭해 주세요. (Colab 설명)
#
# - https://colab.research.google.com/notebooks/welcome.ipynb?hl=ko

# %% [markdown]
# ## **Colab 사용법 익히기**

# %% [markdown]
# ---
# ❓ 이 셀의 밑에 새로운 텍스트 셀(text cell)을 클릭하여 만들고, <br/>
# 그 안에 본인의 이름(굵게)과 좌우명(기울임꼴)을 텍스트 셀에 기입하시기 바랍니다.
#
# 예시:
# > 제 이름은 **조희련**입니다.<br/>
# 좌우명은 '*일하지 않는자여, 먹지도 마라*' 입니다.

# %% [markdown]
# \- \- \-
#
# 👉 [참고] 키보드 쇼트컷으로 셀을 생성, 삭제, 실행하기
#
# https://amitness.com/2020/06/google-colaboratory-tips/#4-jupyter-notebook-keyboard-shortcuts

# %% [markdown]
# ---
# ❓ 간단한 사칙연산을 해보시기 바랍니다.
#
# ```
# 4 + 7
# 3 - 9
# 2 * 8
# 7 / 2
# ```
#
# 이 셀 아래에 '코드 셀(code cell)'을 만든 뒤, 위의 수식을 하나씩 기입한 뒤 실행해 보시기 바랍니다.
#
# 수식에서 띄어쓰기는 하셔도 되고 안하셔도 됩니다. (가독성을 위해 띄어쓰기 권장.)

# %%
4 + 7
# Out:
# 11

# %%
7 / 2
# Out:
# 3.5

# %% [markdown]
# ---
# ❓ 그럼 문장(문자열)을 출력하려면 어떻게 할까요?
#
# ```
# print("Hello, World!")
# ```
#
# 이 셀 아래에 코드 셀을 만들어 위와 같이 **print( )** 함수를 사용하여 "Hello, World!"를 출력하시고,
#
# 또 그 밑에 새로운 코드 셀을 만들어 '안녕, 파이썬!'을 출력해 보시기 바랍니다.
#
# 문자열을 표현할 때에는 **쌍따옴표** 또는 **홑따옴표**로 출력하고자 하는 문자열을 감싸주시면 됩니다.

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
"Hello, World!"   # print 문 없이 곧바로 문자열을 출력했을 때
# Out:
# 'Hello, World!'

# %%
print('안녕, 파이썬!')
# Out:
# 안녕, 파이썬!

# %% [markdown]
# ## **오늘 배울 내용: 파이썬의 다양한 자료형**
# ##### 1. 정수 (integer)
# ##### 2. 부동소수점수 (floating-point number)
# ##### 3. 불 (boolean)
# ##### 4. 문자열 (string)
#
# \-\-\-
#
# **자료형(또는 데이터 타입, Data Type)은 프로그래밍 언어에서 사용할 수 있는**
#
# **데이터(숫자, 문자열, 불리언 등)의 종류를 말합니다.**

# %% [markdown]
# ---
# ### **1. 다양한 사칙 연산**

# %%
19 + 5
# Out:
# 24

# %%
19 - 5
# Out:
# 14

# %%
19 * 5   # 곱하기
# Out:
# 95

# %%
19 / 5   # 나누기
# Out:
# 3.8

# %%
19 // 5   # 몫 구하기
# Out:
# 3

# %%
19 % 5   # 나머지 구하기
# Out:
# 4

# %%
19 ** 5   # 다섯 제곱
# Out:
# 2476099

# %% [markdown]
# ---
# 위에서 '더하기(+)', '빼기(-)', '곱하기(\*)', '나누기(/)' 등 다양한 **연산자**를 살펴 봤는데,
#
# 연산자에는 아래와 같은 우선순위가 있습니다.
#
# 1. 괄호
# 2. 거듭제곱
# 3. 곱셈과 나눗셈
# 4. 덧셈과 뺄셈
# 5. 왼쪽에서 오른쪽으로

# %%
19 + 5 * 2
# Out:
# 29

# %%
(19 + 5) * 2
# Out:
# 48

# %%
19 + 5 ** 2
# Out:
# 44

# %%
(7 * 22 / (19 + (5 - 2))) % 4
# Out:
# 3.0

# %% [markdown]
# ---
# ❓ 187 나누기 3 은?

# %%
187 / 3
# Out:
# 62.333333333333336

# %% [markdown]
# ❓ 1 부터 5 까지의 합은?

# %%
1 + 2 + 3 + 4 + 5
# Out:
# 15

# %% [markdown]
# ❓ 4 명이서 중식당에서 밥을 먹어 9만 8천 원이 나왔고, 이를 n 분의 1로 나눴을 때 1인당 밥값은?

# %%
98000 / 4
# Out:
# 24500.0

# %% [markdown]
# ❓ 25 의 제곱근(square root)은?

# %%
25 ** (1/2)
# Out:
# 5.0

# %%
25 ** (1/2)
# Out:
# 5.0

# %% [markdown]
# ❓ 밑변이 3 이고 높이가 4 인 삼각형의 넓이는?

# %%
3 * 4 / 2
# Out:
# 6.0

# %% [markdown]
# ❓ 반지름(r: radius)의 길이가 7cm 인 원의 둘레(circumference)는?
#
# $C=2 \pi r$
#
# $\pi=3.14$

# %%
2 * 3.14 * 7
# Out:
# 43.96

# %% [markdown]
# ---
# ❓ 이차방정식의 근을 구하세요.
#
# $x=\frac{-b \pm \sqrt{b^2 -4ac}}{2a}$
#
# $7x^2+8x-11=0$

# %% [markdown]
# \- \- \-
#
# 이차방정식의 근 구하는 법
#
# https://ko.wikihow.com/%EC%9D%B4%EC%B0%A8%EB%B0%A9%EC%A0%95%EC%8B%9D%EC%9D%98-%EA%B7%BC-%EA%B5%AC%ED%95%98%EB%8A%94-%EB%B2%95
#
# 위 링크에 나와 있는 해(解)가 출력되도록 위의 근의 공식을 적용한 수식을 파이썬 코드로 작성해 주세요.
#
# ```
# x = 0.81, x = -1.95
# ```

# %%
(-8 + ((8 ** 2) - (4 * 7 * -11))**(1/2)) / (2 * 7)
# Out:
# 0.8062358229989935

# %%
(-8 - ((8 ** 2) - (4 * 7 * -11))**(1/2)) / (2 * 7)
# Out:
# -1.9490929658561365

# %% [markdown]
# ---
# ### **2. 주요 자료형 확인**

# %% [markdown]
# - 정수 : **int**eger
# - 부동소수점수 : **float**ing-point number (실수)
# - 불\* : **bool**ean (True / False)
# - 문자열 : **str**ing
#
# \- \- \-
#
# \* 불리언은 **논리 자료형**이라고도 하며, **참**과 **거짓**을 나타낼 때 씁니다.

# %% [markdown]
# ---
# **type( )** 함수를 써서 파이썬의 자료형을 확인해 볼 수 있습니다.

# %%
type(1)
# Out:
# int

# %%
type(1.0)
# Out:
# float

# %%
type(True)
# Out:
# bool

# %%
type("Hello, World!")
# Out:
# str

# %% [markdown]
# ---
# ❓ 그럼 아래는 각각 어떤 자료형일까요?
# ```
# 37 - 15
# 5 * 2.8
# False
# "안녕하세요"
# 6 / 2
# ```
# 아래에 코드 셀을 만들어 type() 함수 안에 위의 수식을 하나씩 넣어서 실행해 보세요.

# %%
type(37 - 15)
# Out:
# int

# %%
type(5 * 2.8)
# Out:
# float

# %%
type(False)
# Out:
# bool

# %%
type("안녕하세요")
# Out:
# str

# %%
type(6 / 2)   # 계산 결과가 정수가 아님에 주의
# Out:
# float

# %% [markdown]
# ---
# ❓ 만약 **type( )** 함수를 사용할 때 괄호를 닫기 전에 줄바꿈을 할 경우 어떻게 될까요?
# ```
# type( 3 *
# 2)
# ```

# %%
type( 3 *
2)
# Out:
# int

# %% [markdown]
# ---
# ❓ 그렇다면 **print( )** 함수에서의 괄호를 닫기전에 줄바꿈을 할 경우는?

# %%
print(3 *
2)
# Out:
# 6

# %%
'''
아래의 코드 앞에 있는 샤프(#) 기호를 제거하고 실행해 보세요.
# 기호는 주석(comment)을 표시할 때 코드 맨 왼쪽에 사용되며,
실행되지 않습니다.

에러가 나옵니다.
'''

# print("안녕하세요.
# 반갑습니다.")
# Out:
# '\n아래의 코드 앞에 있는 샤프(#) 기호를 제거하고 실행해 보세요.\n# 기호는 주석(comment)을 표시할 때 코드 맨 왼쪽에 사용되며,\n실행되지 않습니다.\n\n에러가 나옵니다.\n'

# %% [markdown]
# ---
# ### **3. 정수와 부동소수점수 다루기**

# %% [markdown]
# ---
# ❓ 앞서 다양한 사칙연산을 실행해 봤는데, 만약에 수식을 쓰다 말거나 불완전하게 작성하면 어떻게 될까요?
#
# ```
# 3 * (4 +
# 3 * + 4
# 3 + * 4
# ```

# %%
# 3 * (4 +

# %%
3 * + 4
# Out:
# 12

# %%
# 3 + * 4

# %% [markdown]
# ---
# ❓ 이번에는 줄바꿈으로 수식을 표현하면 어떻게 될까요?
# ```
# 3 + (4 *
# 2)
# ```

# %%
3 + (4 *
2)
# Out:
# 11

# %% [markdown]
# ---
#
# 👉 지금까지 실행한 수식이나 **type( )** 함수를 이용한 자료형 확인 코드를
#
# **표현식(expression)** 이라고 합니다.
#
# 각 표현식은 실행된 후 **하나의 값으로 평가(evaluate)** 됩니다.
#
# \- \- \-
#
# 예를 들어 표현식 **3 * 4** 는 **12** 라는 값으로 평가됩니다.

# %% [markdown]
# ---
# 그런데 위에서 우리는 6 / 2 가 3.0 으로 평가되는 것을 확인했습니다.
#
# 정수의 나눗셈이 부동소수점수를 돌려준 것입니다.🤔

# %%
6 / 2
# Out:
# 3.0

# %% [markdown]
# 반면 몫을 구하는 표현식은 정수를 돌려줍니다.
# ```
# 6 // 2
# ```

# %%
6 // 2
# Out:
# 3

# %% [markdown]
# **여기서 알 수 있는 것은 연사자 마다 돌려주는 자료형이 다르다는(정의되어 있다는) 것입니다.**

# %% [markdown]
# ---
# 그렇다면 6 / 2 를 했는데, 정수를 출력하고 싶다면 어떻게 해야 할까요?
#
# **int( )** 함수를 쓰면 입력값을 정수로 변환해 줍니다. (소수점 버림)

# %%
int(6 / 2)
# Out:
# 3

# %%
int(3.14)
# Out:
# 3

# %% [markdown]
# ---
# ❓ 정수로 딱 떨어지는 나눗셈 계산식을 작성한 후,
#
# 계산식을 그대로 실행한 경우와
#
# int( ) 함수에 넣어서 결과를 출력한 경우를 비교해 보세요.

# %%
15 / 5
# Out:
# 3.0

# %%
int(15 / 5)
# Out:
# 3

# %% [markdown]
# ---
# 그렇다면 반대는 어떨까요?
#
# 정수를 소수점으로 표현할 수 있을까요?
#
# 네, **float( )** 함수를 쓰면 정수를 소수점으로 표현할 수 있습니다.

# %%
float(37)
# Out:
# 37.0

# %%
float(37.0)
# Out:
# 37.0

# %% [markdown]
# ---
# ❓ 그렇다면 **문자열로 표현된 숫자**는 어떨까요?
# ```
# type("안녕")
# type("1")
# type("37.0")
# ```
# 위 세 함수는 모두 어떤 자료형을 출력할까요?

# %%
type("안녕")
# Out:
# str

# %%
type("1")
# Out:
# str

# %%
type("37.0")
# Out:
# str

# %% [markdown]
# ---
# ❓ 그렇다면 아래와 같이 문자열로 표현되 숫자는 각각의 함수를 통해 어떤 자료형으로 출력될까요?
# ```
# int("1")
# float("1")
# int("37.0")
# float("37.0")
# ```

# %%
int("1")
# Out:
# 1

# %%
float("1")
# Out:
# 1.0

# %%
# int("37.0")   # 에러가 발생합니다.

# %%
float("37.0")
# Out:
# 37.0

# %% [markdown]
# ---
# ❓ 위 함수들을 type( ) 함수에 넣어서 자료형을 확인해 보세요.
# ```
# 예: type(int("1"))
# ```

# %%
type(int("1"))
# Out:
# int

# %%
type(float("1"))
# Out:
# float

# %%
type(float("37.0"))
# Out:
# float

# %% [markdown]
# ---
# 파이썬에서 **부동소수점수**를 표현하는 방법은 다양합니다.
# ```
# 45.8
# 7.     # 뒤에 0 이 생략됐습니다.
# .34     # 앞에 0 이 생략됐습니다.
# ```
# 모두 부동소수점수입니다.

# %%
type(45.8)
# Out:
# float

# %%
type(7.)
# Out:
# float

# %%
type(.34)
# Out:
# float

# %% [markdown]
# ---
# 부동소수점수의 경우 계산 결과가 딱 떨어지지 않는 경우가 종종 발생합니다. (오차 존재)
#
# 아래와 같이 정수를 이용한 계산이 부동소수점수보다 더 정확한 경우가 생깁니다.

# %%
0.1 + 0.2
# Out:
# 0.30000000000000004

# %%
(1 + 2) / 10
# Out:
# 0.3

# %%
# 2.0 ** 1024    # 에러가 발생합니다.

# %%
2 ** 1024    # 정수를 이용하면 계산이 됩니다.
# Out:
# 

# %% [markdown]
# ---
# 부동소수점수에서 소수점에 오차 부분을 자르고 싶을 때,
#
# **round( )** 함수(반올림 함수)를 쓰면 좋습니다.

# %%
round(0.1 + 0.2, 1)   # 맨 끝의 1은 소수점 1자리수까지 표시하라고 지정하고 있습니다.
# Out:
# 0.3

# %% [markdown]
# **help( )** 함수는 함수에 대한 설명을 출력해 줍니다.

# %%
help(round)   # help() 함수 안에 함수명을 넣음
# Out:
# Help on built-in function round in module builtins:
#
# round(number, ndigits=None)
#     Round a number to a given precision in decimal digits.
#
#     The return value is an integer if ndigits is omitted or None.  Otherwise
#     the return value has the same type as the number.  ndigits may be negative.

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
#     file:  a file-like object (stream); defaults to the current sys.stdout.
#     sep:   string inserted between values, default a space.
#     end:   string appended after the last value, default a newline.
#     flush: whether to forcibly flush the stream.

# %% [markdown]
# ---
# ### **4. 불(boolean)과 비교 연산자/논리 연산자**

# %% [markdown]
# **불(bool, boolean)** 자료형은 **True** 와 **False** 의 값을 가집니다.
#
# 아래와 같은 등식, 부등식 명제는 불 값으로 평가됩니다.
#
# ```
# 2 == 3   # 2 와 3은 같은가?
# 2 != 3   # 2 와 3은 다른가(not equal 인가)?
# 2 < 3   # 2 는 3보다 작은가?
# 2 >= 3   # 2는 3보다 크거나 같은가?
# ```

# %% [markdown]
# ---
# ❓ 위 표현식을 하나하나 실행해 보고 결과값을 확인하세요.

# %%
2 == 3
# Out:
# False

# %%
2 != 3
# Out:
# True

# %%
2 < 3
# Out:
# True

# %%
2 >= 3
# Out:
# False

# %% [markdown]
# ---
# 불 자료형은 **and, or, not**과 같은 논리 연산자를 사용하여 연산할 수 있습니다.
# ```
# True and True
# True or False
# not True
# ```

# %% [markdown]
# ---
# ❓ 위 표현식을 하나하나 실행해 보고 결과값을 확인하세요.

# %%
True and True
# Out:
# True

# %%
True or True
# Out:
# True

# %%
not True
# Out:
# False

# %% [markdown]
# ---
# ❓ 비교 연산자와 논리 연산자를 결합한 표현식을 만들고 실행해 보세요.
# ```
# 예: (2 == 3) or (3 != 4)
# ```

# %%
(2 == 3) or (3 != 4)
# Out:
# True

# %% [markdown]
# ---
# 👉 이 개념은 좀 생소할 수 있는데, **파이썬에서는 불(bool)을 정수의 특수한 경우**로 정의하고 있습니다.
#
# 따라서 **True 는 1 이고, False 는 0** 으로 다뤄집니다.

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %% [markdown]
# ---
# **isinstance( )** 라는 함수는 특정 데이터가 특정 자료형인지를 확인해 줍니다.
#
# 평가 결과는 True 또는 False 입니다.
#
# 아래와 같이 사용합니다.
#
# ```
# isinstance(값, 자료형)
# ```

# %%
help(isinstance)
# Out:
# Help on built-in function isinstance in module builtins:
#
# isinstance(obj, class_or_tuple, /)
#     Return whether an object is an instance of a class or of a subclass thereof.
#
#     A tuple, as in ``isinstance(x, (A, B, ...))``, may be given as the target to
#     check against. This is equivalent to ``isinstance(x, A) or isinstance(x, B)
#     or ...`` etc.

# %%
isinstance(1, int)
# Out:
# True

# %%
isinstance("안녕", str)
# Out:
# True

# %%
isinstance(True, bool)
# Out:
# True

# %%
isinstance(True, int)
# Out:
# True

# %%
(True == 1) and (False == 0)
# Out:
# True

# %% [markdown]
# ---
# 앞서 우리가 int("1") 과 같이 문자열로 된 숫자를 정수로 변환한 것처럼
#
# **bool( )** 함수도 입력된 값을 불로 변환할 수 있습니다.

# %% [markdown]
# ---
# ❓ 아래를 각각 실행해보세요.
# ```
# bool(0)
# bool(5)
# bool(2.3)
# bool(-5)
# bool("ㅋ")
# bool('')    # 빈 문자열 - 홑따옴표 사이에 아무런 글자가 없습니다.
# ```

# %%
bool(0)
# Out:
# False

# %%
bool(5)
# Out:
# True

# %%
bool(2.3)
# Out:
# True

# %%
bool(-5)
# Out:
# True

# %%
bool("ㅋ")
# Out:
# True

# %%
bool('')
# Out:
# False

# %%
0 == False
# Out:
# True

# %% [markdown]
# ---
# ### **5. 문장(statement)과 할당문(assignment statement)**

# %% [markdown]
# **문장(statement)** 은 실행가능한 코드의 단위입니다.
#
# *A statement is an instruction that a Python interpreter can execute.*
#
# 문장의 예로 **할당문(assignment statement)**이 있습니다.
#
# ```
# name = '조희련'
# date = '2022/08/22'
# non_covid = True
# ```
#
# 할당문은 **이름(변수명), 할당 연산자(=), 표현식**의 형태로 씁니다.

# %%
has_siblings = False
has_siblings
# Out:
# False

# %%
happy = True
happy
# Out:
# True

# %%
money = 100
money
# Out:
# 100

# %%
money * 2
# Out:
# 200

# %%
탕수육 = 25000

# %%
탕수육 * 2
# Out:
# 50000

# %% [markdown]
# ---
# 할당문에서 변수를 정의하게 되는데, 이때 변수명을 지을 때 지켜야할 사항들이 있습니다.
#
# 1. 파이썬 키워드를 쓸 수 없습니다. (파이썬 키워드:
# https://realpython.com/python-keywords/)
#
# 2. 특수 문자는 _(밑줄)만 허용됩니다.
#
# 3. 숫자로 시작하면 안 됩니다.
#
# 4. 공백을 포함할 수 없습니다.
#
# 영어와 숫자와 밑줄만 사용하고, mobile_phone 과 같이 여러 단어로 된 이름을 만들고 싶을 때,
#
# 밑줄로 단어 경계를 표시하고, 모두 영어 소문자로 작성하는 것이 좋습니다.

# %%
help("keywords")   # 변수명에 파이썬 키워드를 사용해서는 안됩니다.
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %% [markdown]
# ---
# ❓ 이름, 생년월일, 휴대폰 번호, 좋아하는 숫자, 백신 접종 여부에 대한
#
# 할당문을 작성해 주세요. (총 5개)

# %%
name = '홍길동'

# %%
birth_date = '2000/02/22'

# %%
mobile_phone = '010-9999-0000'

# %%
favorite_number = 7

# %%
vaccinated = True

# %% [markdown]
# ---
# ### **6. 할당문을 활용한 간단한 계산**

# %% [markdown]
# 동호회 회원 10명이 커피 전문점에 왔습니다.
#
# 메뉴는 아래와 같이 아이스 아메리카노, 따뜻한 아메리카노, 아이스 카페라떼, 따뜻한 카페라떼, 에스프레소 입니다.
#
# - ice_coffee : 2500
# - hot_coffee : 2000
# - ice_cafe_latte : 3500
# - hot_cafe_latte : 3000
# - espresso : 1500
#
# 주문 결과 아이스 아메리카노 4잔, 아이스 카페라떼 3잔, 따뜻한 아메리카노 2잔, 에스프레소 1잔을 시켰습니다.
#
# 합계 금액을 계산하고 sum 이라는 변수에 합계 금액을 담은 뒤(할당문 사용),
#
# sum 을 print( )문을 이용하여 출력해 보겠습니다.

# %%
ice_coffee = 2500
hot_coffee = 2000
ice_cafe_latte = 3500
hot_cafe_latte = 3000
espresso = 1500

# %%
sum = ice_coffee * 4 + ice_cafe_latte * 3 + hot_coffee * 2 + espresso * 1
print(sum)
# Out:
# 26000

# %% [markdown]
# ---
# ❓ 학생 30명이 북경반점에서 먹은 점심 식사의 1인당 회비를 계산해 주세요.
#
# * 탕수육 : 23,000원 (5개)
# * 유산슬 : 28,000원 (3개)
# * 고추잡채 : 25,000원 (4개)
# * 짜장면 : 5,000원 (15개)
# * 짬뽕 :  6,000원 (15개)
#
# 할당문을 이용하여 회비 계산 문제를 풀어 보세요.
#
# **출력 결과(output)**
# ```
# 1인당 회식비는 XXXXX원 입니다.
# ```
#
# **출력문 힌트**
# ```
# print("1인당 회식비는", sum, "원 입니다.")
# ```

# %%
탕수육 = 23000
유산슬 = 28000
고추잡채 = 25000
짜장면 = 5000
짬뽕 = 6000

number_of_students = 30

ts = 5   # 탕수육 주문 개수
ys = 3
gc = 4
cc = 15
cp = 15

total = 탕수육 * ts + 유산슬 * ys + 고추잡채 * gc + 짜장면 * cc + 짬뽕 * cp

pay_per_person = total / number_of_students

print("1인당 회식비는", pay_per_person, "원 입니다.")
# Out:
# 1인당 회식비는 15466.666666666666 원 입니다.

# %%
int(pay_per_person)   # 정수만 남습니다.
# Out:
# 15466

# %%
round(pay_per_person, -2)   # 백단위에서 반올림됩니다.
# Out:
# 15500.0

# %%
int(round(pay_per_person, -2))   # 정수로 변환됩니다.
# Out:
# 15500

# %%
print("1인당 회식비는", int(round(pay_per_person, -2)), "원 입니다.")
# Out:
# 1인당 회식비는 15500 원 입니다.

# %% [markdown]
# ---
# ❓ 한 샌드위치 가게에서 손님 맞춤형 샌드위치를 팔고 있습니다.
#
# - 양상치: 100원 (lettuce)
# - 햄: 200원 (ham)
# - 계란: 300원 (egg)
# - 호밀빵: 500원 (bread_rye)
# - 흰빵: 400원 (bread_white)
# - 치즈: 150원 (cheeze)
#
# 아래와 같은 고객1과 고객2가 샌드위치를 주문했습니다.
#
# 맨 하단의 내용이 출력되도록 프로그램을 작성해 주세요.
#
# >고객1 주문 내용: 흰빵에 햄 2장, 계란 2개, 양상치 3개를 넣은 샌드위치. <br/>
# >고객2 주문 내용: 호밀빵에 치즈 2장, 햄 3장, 양상치 1개, 계란 1개를 넣은 샌드위치.
#
# ```
# 고객1 주문 금액: 1700
# 고객2 주문 금액: 1800
# ```

# %%
lettuce = 100
ham = 200
egg = 300
bread_rye = 500
bread_white = 400
cheeze = 150

order_1 = bread_white * 1 + ham * 2 + egg * 2 + lettuce * 3
order_2 = bread_rye * 1 + cheeze * 2 + ham * 3 + lettuce * 1 + egg * 1

print("고객1 주문 금액:", order_1)
print("고객2 주문 금액:", order_2)
# Out:
# 고객1 주문 금액: 1700
# 고객2 주문 금액: 1800

# %% [markdown]
# ---
# ### **7. 문자열**

# %% [markdown]
# **문자열(string)**은 말 그대로 **'문자들의 열(sequence of characters)'**입니다.
#
# 글자, 단어, 문장, 단락 등을 모두 문자열로 표현할 수 있습니다.
#
# 문자열에는 다음과 같은 연산이 가능합니다.
#
# - 연결(concatenation) : '안녕' + '! 세계야'
#
# - 반복(repetition) : '안녕' * 3
#
# - 비교(comparison) : '안녕' < '안녕!'

# %%
'안녕' + '! 세계야'   # 연결
# Out:
# '안녕! 세계야'

# %%
'안녕 ' * 3   # 반복
# Out:
# '안녕 안녕 안녕 '

# %%
'안녕' < '안경'   # 비교
# Out:
# False

# %% [markdown]
# ---
# 하지만 자료형에 맞지 않는 연산을 할 경우 에러가 납니다.
#
# 아래는 에러가 발생하는 연산의 예입니다.
# ```
# '안녕' * '!'
# 3 + '안녕'
# '안녕하세요' < 11111
# ```
# **따라서 자료형에 적합한 연산을 이해하고 사용해야 합니다.**

# %% [markdown]
# ---
# 문자열로 표현된 숫자를 숫자(정수, 부동소수점수)로 변환할 수 있듯이,
#
# 숫자도 문자열로 변환할 수 있습니다.
#
# ```
# str(1)
# str(-3.7)
# ```

# %%
str(1)
# Out:
# '1'

# %%
type(str(1))
# Out:
# str

# %%
str(-3.7)
# Out:
# '-3.7'

# %%
str(14800) + '원'
# Out:
# '14800원'

# %%
# 14800 + '원'   # 에러가 발생합니다.

# %% [markdown]
# ---
# 문자열은 문자 하나 하나를 연결한 것이기 때문에
#
# 문자열의 첫 번째 문자, 세 번째 문자, 다섯 번째 문자 등을 선택할 수 있습니다.
#
# 이때 선택하고자 하는 문자를 **문자가 놓여있는 위치(인덱스, index)**로 지정하게 되는데,
#
# 이렇게 위치를 이용하여 원하는 문자 한 글자를 선택하는 것을 **인덱싱(indexing)** 이라고 합니다.
#
# 이때 **맨 처음(왼쪽의) 글자가 놓여 있는 위치의 인덱스의 값은 0 (zero)** 입니다.

# %%
"안녕하세요"[0]
# Out:
# '안'

# %%
"안녕하세요"[1]
# Out:
# '녕'

# %%
"안녕하세요"[3]
# Out:
# '세'

# %%
"안녕하세요"[1:5]
# Out:
# '녕하세요'

# %% [markdown]
# ---
# 비단 한 글자뿐만 아니라 "안녕하세요"의 "안녕"처럼 구간을 지정하여 부분 문자열을 선택할 수 있는데
#
# 이렇게 연속된 글자 구간을 선택하는 것을 **슬라이싱(slicing)** 이라고 합니다.
# ```
# "안녕하세요"[0:2]
# "안녕하세요"[3:]
# "안녕하세요"[:3]
# ```
# 위의 표현식을 각각 실행하여 어떤 결과가 나오는지 확인해 보세요.

# %%
"안녕하세요"[0:2]
# Out:
# '안녕'

# %%
"안녕하세요"[3:]
# Out:
# '세요'

# %%
"안녕하세요"[:3]
# Out:
# '안녕하'

# %% [markdown]
# ---
# 만약 **맨 끝(오른쪽)의 글자**를 기준으로 선택하고 싶다면 **마이너스(-) 인덱스**를 사용하면 됩니다.
# ```
# "안녕하세요"[-1]
# "안녕하세요"[-2:]
# "살찐꼬리난쟁이여우원숭이"[-3:]
# ```

# %%
"안녕하세요"[-1]
# Out:
# '요'

# %%
"안녕하세요"[-2:]
# Out:
# '세요'

# %%
"살찐꼬리난쟁이여우원숭이"[-3:]
# Out:
# '원숭이'

# %% [markdown]
# ---
# ❓ 아래의 주석(comment, # 표시)을 하나씩 제거한 뒤 어떤 결과가 나오는지 실행해 보세요.

# %%
message = "룰루랄라 신난다"
reply = "노래 부르자"

# message[0]
# print(message[0])
# message[1:4]
# print(message[1:4])
# message[-1]   # 뒤에서 선택
# message[-3:-1]
# message[-3:]
# message * 2
# print(message * 2)
# print(message + message)
print(message, message, sep = '')
# Out:
# 룰루랄라 신난다룰루랄라 신난다

# %%
help(print)   # sep 옵션은 출력하려는 문자열들 사이의 들어갈 문자를 지정합니다.
# Out:
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
#     file:  a file-like object (stream); defaults to the current sys.stdout.
#     sep:   string inserted between values, default a space.
#     end:   string appended after the last value, default a newline.
#     flush: whether to forcibly flush the stream.

# %% [markdown]
# ---
# **빈 문자열(empty string)**을 사용하는 경우가 있습니다.
#
# 아래와 같이 쌍따옴표 또는 홑따옴표 사이에 아무 글자도 넣지 않은채 따옴표를 닫는 것으로 정의합니다.
# ```
# ""
# ''
# ```
# *An empty string is a string instance of zero length.*
#
# **len( )** 함수로 문자열의 길이를 세어 볼 수 있는데,
#
# 빈 문자열은 문자열의 길이가 0 (zero) 입니다.

# %%
empty_str = ""

# %%
# len 은 길이를 돌려주는 함수입니다.

len(empty_str)
# Out:
# 0

# %%
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %%
len("안녕하세요")
# Out:
# 5

# %%
bool(empty_str)   # 위에서 확인했듯이 빈 문자열은 False로 평가됩니다.
# Out:
# False

# %% [markdown]
# ---
# ❓ 아래의 주석을 하나씩 제거한 뒤 실행해 보세요.

# %%
message = "룰루랄라 신난다"
reply = "노래 부르자"

# print("")
# type("")
# print(type(""))
# message + "" + reply
# message + "\t" + reply    # \t = 탭(공백 문자)
# print(message + "\t" + reply)
# message + "\n" + reply     # \n = 줄바꿈(공백 문자)
# print(message + "\n" + reply)
# message + " " + "같이 나가자"
# message + " 같이 나가자"
# print(message, "같이 나가자")

# %% [markdown]
# ---
# 문자열을 출력할 때 따옴표를 출력하고 싶을 때가 있습니다.
# ```
# 철수가 말했다. "영희야, 놀자!"
# ```
# 그런데 문자열을 나타낼 때 사용하는 기호가 쌍따옴표/홑따옴표 입니다.
#
# 어떻게 해야 할까요?

# %%
print("쌍따옴표 출력: \"")   # 따옴표 앞에 backslash \ 기호를 넣음
print('쌍따옴표 출력: "')   # 홑따옴표로 문자열을 감싸고 쌍따옴표를 출력
# Out:
# 쌍따옴표 출력: "
# 쌍따옴표 출력: "

# %%
print('갑자기 그가 "악!"하고 외쳤다.')
# Out:
# 갑자기 그가 "악!"하고 외쳤다.

# %% [markdown]
# ---
# ❓ 아래와 같은 문자열들이 있습니다.
#
# ```
# girl = "영희가 외쳤다."
# joy = "룰루랄라 신난다!"
# sing = "노래를 부르자!"
# ```
# 문자열의 슬라이싱, 연결(concatenation), 쌍따옴표 삽입으로 아래의 문장을 만들어 주세요.
#
# **영희가 "룰루랄라 노래를 부르자!" 외쳤다.**

# %%
girl = "영희가 외쳤다."
joy = "룰루랄라 신난다!"
sing = "노래를 부르자!"

print(girl[:4] + '"' + joy[:5] + sing + '"' + girl[3:])
# Out:
# 영희가 "룰루랄라 노래를 부르자!" 외쳤다.

# %% [markdown]
# ---
# 여러 줄로 된 문자열을 표현하고 싶을 수도 있습니다.
#
# 이 경우 아래와 같이 세 번 연달아 홑따옴표, 쌍따옴표를 써서 줄바꿈 문자열을 표현합니다.
#
# ```
# multiline = '''
# 안녕하세요.
# 만나서 반가워요.
# ```

# %% [markdown]
# ---
# ❓ 위와 같이 할당문을 정의한 후
#
# print( ) 문으로 multiline을 출력해 보세요.

# %%
multiline = '''
안녕하세요.
만나서 반가워요.
'''
print(multiline)
# Out:
# 안녕하세요.
# 만나서 반가워요.

# %% [markdown]
# ---
# 아래와 같이 줄바꿈 문장을 표현하면 줄바꿈이 조금 다르게 표현됩니다.
# ```
# multiline = '''안녕하세요.
# 만나서 반가워요.'''
# ```

# %%
multiline = '''안녕하세요.
만나서 반가워요.'''

print(multiline)
# Out:
# 안녕하세요.
# 만나서 반가워요.

# %% [markdown]
# ---
# **format( ) 함수**를 이용하여 문자열을 출력하면, 문자열의 원하는 곳에 변수를 쉽게 집어 넣을 수 있습니다.
#
# 문자열 안에 변수가 올 위치에 중괄호(curly braces)를 넣은 뒤, 맨 뒤의 괄호 안에 변수명을 넣으면 됩니다.
# ```
# 예: "편의점에 {}와 {}가 들어왔습니다.".format(변수1, 변수2, ...)
# ```

# %%
name = "이영희"
rank = 2

print("고객명은 {}이고, 신용등급은 {}등급이다.".format(name, rank))
# Out:
# 고객명은 이영희이고, 신용등급은 2등급이다.

# %%
"우리의 소원은 {}인데, 그들의 소원은 {}이다".format("합병", "인수")
# Out:
# '우리의 소원은 합병인데, 그들의 소원은 인수이다'

# %% [markdown]
# ---
# ❓ format 함수를 써서 아래의 문장을 print 문을 써서 출력하세요.
#
# ```
# 내가 좋아하는 남배우는 XXX이고, 좋아하는 여배우는 XXX이고, 좋아하는 한국 영화는 'XXX'이다.
# ```
#
# 이때, actor, actress, movie 에 각각 본인이 좋아하는 배우와 영화를 적어 넣으세요.

# %%
print("내가 좋아하는 남배우는 {}이고, 좋아하는 여배우는 {}이고, 좋아하는 한국 영화는 '{}'이다.".format('조승우', '배두나', '비밀의 숲'))
# Out:
# 내가 좋아하는 남배우는 조승우이고, 좋아하는 여배우는 배두나이고, 좋아하는 한국 영화는 '비밀의 숲'이다.

# %% [markdown]
# ---
# ❓ 아래의 문장이 있습니다.
# ```
# sentence = "파티에 총 32명을 불렀는데, 그 중 3명이 불참하였다."
# ```
# 파티에 온 사람들의 총 인원을 계산하고, 아래의 문장이 출력되도록 하세요.
# ```
# "파티에 참석한 사람은 총 29명이다."
# ```
# **힌트**
# - 슬라이싱을 통해 숫자를 선택하세요.
# - invited 와 no_show 에 선택한 숫자를 넣으세요.
# - 이때 숫자를 정수(integer)로 변환하세요.
# - attended = invited - no_show 로 참석자를 계산하세요.
# - fomat( ) 함수를 이용하여 최종 문장을 print 하세요.

# %%
sentence = "파티에 총 32명을 불렀는데, 그 중 3명이 불참하였다."
invited = int(sentence[6:8])
no_show = int(sentence[-10])
attended = invited - no_show

print("파티에 참석한 사람은 총 {}명이다.".format(attended))
# Out:
# 파티에 참석한 사람은 총 29명이다.

# %% [markdown]
# ---
# **in** 이라는 파이썬 키워드를 이용하여 문자열에 특정 문자열이 들어가 있는지를 확인할 수 있습니다.
#
# ❓ 아래를 실행해 보시기 바랍니다.
# ```
# sentence = "눈이 녹으면 봄이 된다."
# print("눈" in sentence)
# print("물" in sentence)
# ```

# %%
sentence = "눈이 녹으면 봄이 된다."
print("눈" in sentence)
print("물" in sentence)
# Out:
# True
# False

# %% [markdown]
# ---
# 👉 Colab 에서는 자료형 뒤에 바로 **'. (마침표)'**를 찍으면 해당 자료형과 관련된 내장 함수(built-in function)를 표시해 줍니다.
# ```
# 내장 함수의 예: 'happy'.upper()   # 알파벳을 대문자로 변환해주는 upper() 함수
# ```

# %%
a = 'happy'
a    # a 뒤에 점을 찍고 기다려 보세요. colab에서 사용 가능한 내장 함수 후보를 제시해 줍니다.
# Out:
# 'happy'

# %% [markdown]
# ---
# ---
# #### **2022 Summer Coding 2 예고**
#
# 다음과 같은 가사가 있습니다. (빅뱅의 '하루하루'에서 발췌.)
#
# ```
# lyrics = """
# 파도처럼 부숴진 내 맘
# 바람처럼 흔들리는 내 맘
# 연기처럼 사라진 내 사랑
# 문신처럼 지워지지 않아
# 한숨만 땅이 꺼지라 쉬죠
# 내 가슴속에 먼지만 쌓이죠
# """
# ```
#
# **split( )** 함수를 이용하면 공백을 기준으로 문자열을 끊어 줍니다.
# ```
# lyrics.split()
# ```

# %%
# 문자열을 정의합니다. (줄바꿈 형태의 문자열)
lyrics = """
파도처럼 부숴진 내 맘
바람처럼 흔들리는 내 맘
연기처럼 사라진 내 사랑
문신처럼 지워지지 않아
한숨만 땅이 꺼지라 쉬죠
내 가슴속에 먼지만 쌓이죠
"""

# %%
print(lyrics)   # lyrics 변수에 문자열이 담겨 있습니다.
# Out:
# 파도처럼 부숴진 내 맘
# 바람처럼 흔들리는 내 맘
# 연기처럼 사라진 내 사랑
# 문신처럼 지워지지 않아
# 한숨만 땅이 꺼지라 쉬죠
# 내 가슴속에 먼지만 쌓이죠

# %%
lyrics.split()   # 공백을 기준으로 문자열을 끊습니다.
# Out:
# ['파도처럼',
#  '부숴진',
#  '내',
#  '맘',
#  '바람처럼',
#  '흔들리는',
#  '내',
#  '맘',
#  '연기처럼',
#  '사라진',
#  '내',
#  '사랑',
#  '문신처럼',
#  '지워지지',
#  '않아',
#  '한숨만',
#  '땅이',
#  '꺼지라',
#  '쉬죠',
#  '내',
#  '가슴속에',
#  '먼지만',
#  '쌓이죠']

# %% [markdown]
# ---
# 바로 위의 마지막 코드의 실행 결과는 **리스트(list)** 라는 자료형 입니다.
#
# 2022 Summer Coding 2 에서는
#
# **반복되는 자료형(리스트, 튜플, 집합, 딕셔너리)**에 대해 배우겠습니다.
